# %% [markdown]
# EDA

# %% [markdown]
# Data Mining

# %%
import pandas as pd
df = pd.read_csv('emp2.csv')

# %%
df.head(5)
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 0    Douglas    Male  08-06-1993        12:42 PM   97308   6.945
# 1     Thomas    Male   3/31/1996        06:53 AM   61933   4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3      Jerry    Male  03-04-2005        01:00 PM  138705   9.340
# 4      Larry    Male   1/24/1998        04:47 PM  101004   1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.sample(5)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 666     Harold     NaN  02-04-2004        11:02 AM   79459   7.776
# 700      Frank    Male  03-02-2009        09:15 PM   78891   7.927
# 228      Bobby    Male   9/23/1994        01:29 AM   51685  17.445
# 995      Henry     NaN  11/23/2014        06:09 AM  132483  16.655
# 839      Joyce  Female   7/25/2001        06:04 AM   51065  16.807
#
#     Senior Management                  Team
# 666              True  Business Development
# 700              True          Distribution
# 228              True           Engineering
# 995             False          Distribution
# 839             False       Human Resources

# %%
df.isnull()
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus  \
# 0         False   False       False            False   False  False
# 1         False   False       False            False   False  False
# 2         False   False       False            False   False  False
# 3         False   False       False            False   False  False
# 4         False   False       False            False   False  False
# ..          ...     ...         ...              ...     ...    ...
# 995       False    True       False            False   False  False
# 996       False   False       False            False   False  False
# 997       False   False       False            False   False  False
# 998       False   False       False            False   False  False
# 999       False   False       False            False   False  False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# 3                False  False
# 4                False  False
# ..                 ...    ...
# 995              False  False
# 996              False  False
# 997              False  False
# 998              False  False
# 999              False  False
#
# [1000 rows x 8 columns]

# %%
df.isnull().all()
# Out:
# First Name           False
# Gender               False
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus                False
# Senior Management    False
# Team                 False
# dtype: bool

# %%
df.isnull().any()
# Out:
# First Name            True
# Gender                True
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus                False
# Senior Management     True
# Team                  True
# dtype: bool

# %%
df['Salary'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Salary, Length: 1000, dtype: bool

# %%
df['Salary'].isnull().any()
# Out:
# False

# %%
df['Bonus'].isnull().all()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus              1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#               Salary        Bonus
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %% [markdown]
# Making new data frame df2

# %%
import pandas as pd2
df2 = pd2.read_csv('emp2.csv')

# %%
df2.sample(20)
# Out:
#       First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 167  Christopher    Male  12/24/2011        12:22 PM  142178  17.984
# 397     Clarence    Male   1/13/2005        09:00 AM  116693  13.835
# 860      Phillip    Male  10-07-1984        11:05 AM   36837  14.660
# 873        Jason    Male  05-01-1998        06:05 PM   75607   4.299
# 133         Lois  Female  12/25/1987        04:16 PM  106317   2.235
# 624       Jeremy    Male  11/26/1997        08:22 AM  133033  12.200
# 173      Lillian  Female  12/21/2008        06:51 PM   85446   3.959
# 813       Evelyn  Female  02-10-2002        04:44 AM  123621  19.767
# 136        Henry    Male   4/24/1995        04:18 AM   43542  19.687
# 987       Gloria  Female  12-08-2014        05:08 AM  136709  10.331
# 620        Ralph    Male  03-07-2012        02:25 AM   81215   8.400
# 917        Shawn    Male   3/13/2008        05:36 PM   51667   6.339
# 850      Charles    Male  09-03-1997        10:04 AM  148291   6.002
# 652       Willie    Male  12-05-2009        05:39 AM  141932   1.017
# 312       Gerald    Male   4/16/2001        10:09 PM  121604   1.923
# 669       Joseph     NaN   3/28/1982        01:05 PM   86564  11.879
# 435        Billy    Male  12-01-2006        03:32 PM  144709  10.069
# 93      Virginia     NaN  05-07-1994        05:58 PM  111858   1.601
# 984        Maria  Female  10/15/2011        04:53 PM   43455  13.040
# 690        Bruce    Male   1/28/2007        11:10 PM  134988  13.926
#
#     Senior Management             Team
# 167              True            Sales
# 397              True     Distribution
# 860             False        Marketing
# 873              True            Sales
# 133              True  Client Services
# 624             False            Sales
# 173              True      Engineering
# 813              True        Marketing
# 136             False            Legal
# 987              True          Finance
# 620             False          Finance
# 917             False          Product
# 850             False              NaN
# 652              True      Engineering
# 312              True            Sales
# 669              True              NaN
# 435              True     Distribution
# 93               True            Legal
# 984             False      Engineering
# 690              True            Sales

# %%
df2.isnull().any()
# Out:
# First Name            True
# Gender                True
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus                False
# Senior Management     True
# Team                  True
# dtype: bool

# %%
columns_to_check = ['First Name','Gender','Senior Management','Team']

# %%
all_missing = df2[columns_to_check].isnull().any()

# %%
print(all_missing)
# Out:
# First Name           True
# Gender               True
# Senior Management    True
# Team                 True
# dtype: bool

# %%
all_missing = df2[columns_to_check].isnull().all()

# %%
print(all_missing)
# Out:
# First Name           False
# Gender               False
# Senior Management    False
# Team                 False
# dtype: bool

# %%
any_missing = df2[columns_to_check].isnull().any()

# %%
print(any_missing)
# Out:
# First Name           True
# Gender               True
# Senior Management    True
# Team                 True
# dtype: bool

# %%
any_missing_combination = df2[columns_to_check].isnull().any().all()

# %%
print(any_missing_combination)
# Out:
# True

# %%
any_missing_combination2 = df2[columns_to_check].isnull().any().any()

# %%
print(any_missing_combination2)
# Out:
# True

# %%
mask = df2[columns_to_check].isnull().all(axis=1)

# %%
print(mask)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
mask2 = df2[columns_to_check].isnull().any(axis=1)

# %%
print(mask2)
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
rows_with_missing_values = df2[df.isnull().any(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 rows_with_missing_values = df2[df.isnull().any(axis=1)]
#
# NameError: name 'df' is not defined

# %%
rows_with_missing_values = df2[df2.isnull().any(axis=1)]

# %%
print(rows_with_missing_values)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 1       Thomas    Male   3/31/1996        06:53 AM   61933   4.170
# 7          NaN  Female   7/20/2015        10:43 AM   45906  11.598
# 10      Louise  Female  08-12-1980        09:01 AM   63241  15.132
# 20        Lois     NaN   4/22/1995        07:18 PM   64714   4.934
# 22      Joshua     NaN  03-08-2012        01:58 AM   90816  18.816
# ..         ...     ...         ...             ...     ...     ...
# 961    Antonio     NaN   6/18/1989        09:37 PM  103050   3.050
# 972     Victor     NaN   7/28/2006        02:49 PM   76381  11.159
# 985    Stephen     NaN  07-10-1983        08:10 PM   85668   1.909
# 989     Justin     NaN  02-10-1991        04:58 PM   38344   3.794
# 995      Henry     NaN  11/23/2014        06:09 AM  132483  16.655
#
#     Senior Management             Team
# 1                True              NaN
# 7                 NaN          Finance
# 10               True              NaN
# 20               True            Legal
# 22               True  Client Services
# ..                ...              ...
# 961             False            Legal
# 972              True            Sales
# 985             False            Legal
# 989             False            Legal
# 995             False     Distribution
#
# [236 rows x 8 columns]

# %%
rows_with_missing_values = df2[df2[columns_to_check].isnull().any(axis=1)]

# %%
print(rows_with_missing_values)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 1       Thomas    Male   3/31/1996        06:53 AM   61933   4.170
# 7          NaN  Female   7/20/2015        10:43 AM   45906  11.598
# 10      Louise  Female  08-12-1980        09:01 AM   63241  15.132
# 20        Lois     NaN   4/22/1995        07:18 PM   64714   4.934
# 22      Joshua     NaN  03-08-2012        01:58 AM   90816  18.816
# ..         ...     ...         ...             ...     ...     ...
# 961    Antonio     NaN   6/18/1989        09:37 PM  103050   3.050
# 972     Victor     NaN   7/28/2006        02:49 PM   76381  11.159
# 985    Stephen     NaN  07-10-1983        08:10 PM   85668   1.909
# 989     Justin     NaN  02-10-1991        04:58 PM   38344   3.794
# 995      Henry     NaN  11/23/2014        06:09 AM  132483  16.655
#
#     Senior Management             Team
# 1                True              NaN
# 7                 NaN          Finance
# 10               True              NaN
# 20               True            Legal
# 22               True  Client Services
# ..                ...              ...
# 961             False            Legal
# 972              True            Sales
# 985             False            Legal
# 989             False            Legal
# 995             False     Distribution
#
# [236 rows x 8 columns]

# %%
columns_with_missing_values = df2.columns[df2.isnull().any()].tolist()

# %%
print(df2[columns_with_missing_values])
# Out:
#     First Name  Gender Senior Management                  Team
# 0      Douglas    Male              True             Marketing
# 1       Thomas    Male              True                   NaN
# 2        Maria  Female             False               Finance
# 3        Jerry    Male              True               Finance
# 4        Larry    Male              True       Client Services
# ..         ...     ...               ...                   ...
# 995      Henry     NaN             False          Distribution
# 996    Phillip    Male             False               Finance
# 997    Russell    Male             False               Product
# 998      Larry    Male             False  Business Development
# 999     Albert    Male              True                 Sales
#
# [1000 rows x 4 columns]

# %%
rows_with_empty_values = df2.loc[df2[columns_with_missing_values].isnull().any(axis=1)]

# %%
print(rows_with_empty_values)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 1       Thomas    Male   3/31/1996        06:53 AM   61933   4.170
# 7          NaN  Female   7/20/2015        10:43 AM   45906  11.598
# 10      Louise  Female  08-12-1980        09:01 AM   63241  15.132
# 20        Lois     NaN   4/22/1995        07:18 PM   64714   4.934
# 22      Joshua     NaN  03-08-2012        01:58 AM   90816  18.816
# ..         ...     ...         ...             ...     ...     ...
# 961    Antonio     NaN   6/18/1989        09:37 PM  103050   3.050
# 972     Victor     NaN   7/28/2006        02:49 PM   76381  11.159
# 985    Stephen     NaN  07-10-1983        08:10 PM   85668   1.909
# 989     Justin     NaN  02-10-1991        04:58 PM   38344   3.794
# 995      Henry     NaN  11/23/2014        06:09 AM  132483  16.655
#
#     Senior Management             Team
# 1                True              NaN
# 7                 NaN          Finance
# 10               True              NaN
# 20               True            Legal
# 22               True  Client Services
# ..                ...              ...
# 961             False            Legal
# 972              True            Sales
# 985             False            Legal
# 989             False            Legal
# 995             False     Distribution
#
# [236 rows x 8 columns]

# %%
rows_with_missing_values = df2[df2.isnull().any(axis=1)]

# %%
columns_with_missing_values = df2.columns[df2.isnull().any()].tolist()

# %%
columns_with_missing_values = df2.columns[rows_with_missing_values.isnull().any()].tolist()

# %%
print(columns_with_missing_values)
# Out:
# ['First Name', 'Gender', 'Senior Management', 'Team']

# %%
df2.sample(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2.sample(20)
#
# NameError: name 'df2' is not defined

# %%
import pandas as pd
df3 = pd.read_csv('emp2.csv')

# %%
df3.sample(20)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 348     Philip    Male  08-02-1989        11:21 AM  129968  19.897
# 631      Jason     NaN  03-06-2008        01:20 AM   82873   1.869
# 71      Johnny    Male  11-06-2009        04:23 PM  118172  16.194
# 362     Joshua    Male  11-09-2009        06:32 AM   72893   9.555
# 283       Todd    Male  03-11-2009        03:43 AM  107281   1.612
# 905      Alice  Female  02-09-2013        12:49 AM  121250   4.363
# 758       Carl     NaN   8/18/2007        08:01 AM   98295   7.617
# 582      Harry    Male  11/19/1982        11:25 AM   59277  10.200
# 807       Mary  Female  11-06-2011        08:32 AM  115057   2.089
# 173    Lillian  Female  12/21/2008        06:51 PM   85446   3.959
# 646  Elizabeth  Female   2/21/2010        07:02 AM   79145  19.780
# 552    Barbara  Female  09-02-1991        03:41 PM  127297  11.905
# 747     Ernest    Male   6/30/2001        01:46 PM   61181  16.559
# 373    Kenneth    Male   4/13/1999        10:28 PM   81839  12.072
# 144     Nicole     NaN  03-05-1982        02:28 PM  122717  12.452
# 121   Kathleen     NaN  05-09-2016        08:55 AM  119735  18.740
# 259      Henry    Male  02-06-1995        08:34 AM   89258  15.585
# 270     Thomas    Male  04-06-2011        01:04 PM  103235   9.554
# 654       Carl    Male  12/14/1984        08:49 PM   63395  11.411
# 402    Richard     NaN  11/28/1992        05:05 PM  124655  14.272
#
#     Senior Management                  Team
# 348             False               Finance
# 631             False       Client Services
# 71               True                 Sales
# 362             False          Distribution
# 283              True           Engineering
# 905              True               Finance
# 758              True                 Legal
# 582             False               Finance
# 807             False               Finance
# 173              True           Engineering
# 646             False               Finance
# 552              True               Product
# 747             False  Business Development
# 373             False                 Sales
# 144             False                 Sales
# 121             False               Product
# 259              True       Human Resources
# 270              True       Human Resources
# 654             False                 Legal
# 402              True           Engineering

# %%
df3.info
# Out:
# <bound method DataFrame.info of     First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 0      Douglas    Male  08-06-1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996        06:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male  03-04-2005        01:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998        04:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014        06:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984        06:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013        04:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012        06:24 PM  129949  10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]>

# %%
df3.dropna(inplace = True)

# %%
df3.info
# Out:
# <bound method DataFrame.info of     First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 0      Douglas    Male  08-06-1993        12:42 PM   97308   6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male  03-04-2005        01:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998        04:47 PM  101004   1.389
# 5       Dennis    Male   4/18/1987        01:35 AM  115163  10.125
# ..         ...     ...         ...             ...     ...     ...
# 994     George    Male   6/21/2013        05:47 PM   98874   4.479
# 996    Phillip    Male   1/31/1984        06:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013        04:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012        06:24 PM  129949  10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# 5               False                 Legal
# ..                ...                   ...
# 994              True             Marketing
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [764 rows x 8 columns]>

# %%
df3.describe()
# Out:
#               Salary       Bonus
# count     764.000000  764.000000
# mean    90433.196335   10.148041
# std     32864.665282    5.608733
# min     35013.000000    1.015000
# 25%     62071.750000    5.193250
# 50%     90428.000000    9.658500
# 75%    118075.250000   14.965000
# max    149908.000000   19.944000

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 764 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         764 non-null    object
#  1   Gender             764 non-null    object
#  2   Start Date         764 non-null    object
#  3   Last Login Time    764 non-null    object
#  4   Salary             764 non-null    int64
#  5   Bonus              764 non-null    float64
#  6   Senior Management  764 non-null    object
#  7   Team               764 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 53.7+ KB

# %%
df.isnull().any()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.isnull().any()
#
# NameError: name 'df' is not defined

# %%
df3.isnull().any()
# Out:
# First Name           False
# Gender               False
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus                False
# Senior Management    False
# Team                 False
# dtype: bool

# %%
import pandas as pd
df4 = pd.read_csv('emp2.csv')
df4.sample(20)
# Out:
#      First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 933       Doris  Female  07-05-1993        05:54 PM  141439   3.799
# 454         NaN    Male   2/21/1995        12:26 AM  136602  10.429
# 672      Robert    Male  11-05-1982        12:41 PM  111580  10.982
# 235       Norma  Female  02-11-2015        11:44 PM   94393   3.643
# 888     Marilyn  Female  10-08-2007        12:32 AM  115149  11.934
# 451       Terry     NaN   7/15/2016        12:29 AM  140002  19.490
# 363      Justin     NaN   4/15/2005        08:43 PM   96978  13.865
# 0       Douglas    Male  08-06-1993        12:42 PM   97308   6.945
# 32          NaN    Male   8/21/1998        02:27 PM  122340   6.417
# 657     Rebecca  Female  03-05-2000        10:33 AM   46750  11.367
# 996     Phillip    Male   1/31/1984        06:30 AM   42392  19.675
# 815       Maria     NaN   1/18/1986        08:36 PM  106562   4.000
# 187       Roger    Male  11/19/2004        03:55 PM   51430   6.460
# 368     Marilyn  Female  12/17/1982        12:10 PM  147183   8.748
# 940      Andrew    Male   9/28/1990        09:38 AM  137386   8.611
# 140     Shirley  Female   2/28/1981        01:23 PM  113850   1.854
# 677  Jacqueline  Female   9/20/1994        06:07 PM   62371  15.770
# 616    Kimberly  Female  12-06-1986        02:23 PM   37916  12.929
# 160       Kathy  Female   3/18/2000        07:26 PM  149563  16.991
# 20         Lois     NaN   4/22/1995        07:18 PM   64714   4.934
#
#     Senior Management                  Team
# 933             False  Business Development
# 454               NaN             Marketing
# 672             False       Human Resources
# 235              True           Engineering
# 888              True                 Legal
# 451              True             Marketing
# 363             False               Finance
# 0                True             Marketing
# 32                NaN                   NaN
# 657              True                 Sales
# 996             False               Finance
# 815             False       Human Resources
# 187             False             Marketing
# 368             False  Business Development
# 940              True          Distribution
# 140             False             Marketing
# 677              True       Client Services
# 616              True          Distribution
# 160              True               Finance
# 20               True                 Legal

# %%
df4.dropna(inplace = True)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 764 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         764 non-null    object
#  1   Gender             764 non-null    object
#  2   Start Date         764 non-null    object
#  3   Last Login Time    764 non-null    object
#  4   Salary             764 non-null    int64
#  5   Bonus              764 non-null    float64
#  6   Senior Management  764 non-null    object
#  7   Team               764 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 53.7+ KB

# %%
import matplotlib.pyplot as plt
plt.scatter(df4['Salary'],df4['Bonus'])

# %%
import seaborn as sns
sns.scatterplot(x='Salary',y='Bonus',data=df4)
# Out:
# <Axes: xlabel='Salary', ylabel='Bonus'>

# %%
sns.scatterplot(x='Salary',y='Bonus',data=df4,hue='Gender')
# Out:
# <Axes: xlabel='Salary', ylabel='Bonus'>

# %%
sns.pairplot(df4)

# %%
import ydata_profiling
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import ydata_profiling
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
import pandas as pd
df5 = pd.read_csv('emp2.csv')
df5.sample(5)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 772    Lillian  Female   8/14/2009        05:41 AM  113554  18.018
# 630    Michael    Male   7/13/1988        01:48 PM   47079   2.617
# 922     Arthur    Male  12-05-2013        08:44 AM   86615   3.412
# 712     Martin     NaN  02-06-2001        04:17 AM  123963  15.745
# 660       Mary     NaN  12/24/1986        07:02 PM  100341   6.662
#
#     Senior Management                  Team
# 772              True  Business Development
# 630             False                 Legal
# 922              True  Business Development
# 712              True           Engineering
# 660             False          Distribution

# %%
df5.dropna(inplace = True)

# %%
import seaborn as sns
sns.scatterplot(x='Salary',y='Bonus',data=df5)
# Out:
# <Axes: xlabel='Salary', ylabel='Bonus'>

# %%
import ydata_profiling

# %%
from ydata_profiling import ProfileReport
a = ProfileReport(df5)
a.to_file('report5.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
